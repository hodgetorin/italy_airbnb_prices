# %% [markdown]
# df was already filtered in excel for:
# price between 30 and 250
# room type = home/whole apt
# all cities

# %%
import pandas as pd

# %%
df = pd.read_csv("italy.csv")

# %%
df.head()
# Out:
#        City          id                                               name  \
# 0  Florence   1621152.0  Splendida Casa sullAlbero a Pochi Minuti da Fi...
# 1  Florence  11258736.0  Creative and Unique Home in the Heart of Florence
# 2  Florence  16318436.0  Modern apartment in stunning location, riverfront
# 3  Florence  19060595.0  Big apt with Terrace, Air Con, next Davids Statue
# 4  Florence  19425752.0  Corso Penthouse.Terrace with Duomo view,4bdr 4btr
#
#      host_id    host_name neighbourhood_group      neighbourhood  latitude  \
# 0    5272126        Elena                 NaN  Gavinana Galluzzo  43.73198
# 1    8343063       Matteo                 NaN     Centro Storico  43.78061
# 2  106793109      Massimo                 NaN     Centro Storico  43.76686
# 3  118956463  Max & Laura                 NaN     Centro Storico  43.77961
# 4    6594667      Stefano                 NaN     Centro Storico  43.77165
#
#    longitude         coordinates        room_type  price  minimum_nights  \
# 0   11.21041  43.73198, 11.21041  Entire home/apt    250               1
# 1   11.24350   43.78061, 11.2435  Entire home/apt    250               2
# 2   11.25279  43.76686, 11.25279  Entire home/apt    250               3
# 3   11.26073  43.77961, 11.26073  Entire home/apt    250               1
# 4   11.25569  43.77165, 11.25569  Entire home/apt    250               3
#
#    number_of_reviews last_review  reviews_per_month  \
# 0                591   5/27/2022               5.55
# 1                114  12/10/2021               1.96
# 2                 61   5/22/2022               0.94
# 3                 29   8/26/2021               0.49
# 4                114   5/27/2022               1.93
#
#    calculated_host_listings_count  availability_365  number_of_reviews_ltm  \
# 0                              13               266                     82
# 1                               2               150                      3
# 2                               1               157                      7
# 3                               6                 0                      4
# 4                              10               217                     23
#
#   license
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  3.222300e+04  3.222300e+04  32223.000000  32223.000000  32223.000000
# mean   1.798039e+16  1.328672e+08     40.641317     14.214079     97.259163
# std    1.008735e+17  1.282653e+08      3.028956      2.713999     47.195756
# min    3.079000e+03  1.944000e+03     35.496390      9.032091     30.000000
# 25%    1.540379e+07  2.390487e+07     38.018105     11.674735     62.000000
# 50%    3.058342e+07  8.770104e+07     40.217650     14.274290     85.000000
# 75%    4.460417e+07  2.136174e+08     43.767810     16.869705    120.000000
# max    6.350000e+17  4.657925e+08     46.524850     18.494770    250.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    32223.000000       32223.000000       32223.000000
# mean         3.404370          20.705583           0.493911
# std         12.647679          41.694570           0.676461
# min          1.000000           1.000000           0.020000
# 25%          2.000000           3.000000           0.130000
# 50%          2.000000           7.000000           0.260000
# 75%          4.000000          20.000000           0.550000
# max        999.000000         894.000000          10.070000
#
#        calculated_host_listings_count  availability_365  number_of_reviews_ltm
# count                    32223.000000      32223.000000           32223.000000
# mean                        18.983521        203.515315               4.687677
# std                         98.769800        117.399536               7.324630
# min                          1.000000          0.000000               0.000000
# 25%                          1.000000         99.000000               1.000000
# 50%                          2.000000        221.000000               2.000000
# 75%                          5.000000        313.000000               5.000000
# max                       1059.000000        365.000000             144.000000

# %% [markdown]
# Null Hypothesis:
# The mean price of the cities are equal, there is no variation.
#
# Alt Hypothesis:
# at least one group mean is different. All means are not equal.

# %%
df.drop_duplicates()
# Out:
#            City            id  \
# 0      Florence  1.621152e+06
# 1      Florence  1.125874e+07
# 2      Florence  1.631844e+07
# 3      Florence  1.906060e+07
# 4      Florence  1.942575e+07
# ...         ...           ...
# 32218    Sicily  5.870000e+17
# 32219    Sicily  1.530048e+07
# 32220  Trentino  4.395053e+06
# 32221  Trentino  1.403348e+07
# 32222  Trentino  1.681060e+07
#
#                                                     name    host_id  \
# 0      Splendida Casa sullAlbero a Pochi Minuti da Fi...    5272126
# 1      Creative and Unique Home in the Heart of Florence    8343063
# 2      Modern apartment in stunning location, riverfront  106793109
# 3      Big apt with Terrace, Air Con, next Davids Statue  118956463
# 4      Corso Penthouse.Terrace with Duomo view,4bdr 4btr    6594667
# ...                                                  ...        ...
# 32218                                      Casa Raffaela  450487112
# 32219                 Villa Sara nella riviera siciliana   96552608
# 32220  Appartamento trilocale panoramico Passo del To...   22815635
# 32221                    Appartamento sulle piste da sci   84043154
# 32222         Luminosa Mansarda a Molveno APT Zeni Carlo  111800151
#
#          host_name neighbourhood_group      neighbourhood   latitude  \
# 0            Elena                 NaN  Gavinana Galluzzo  43.731980
# 1           Matteo                 NaN     Centro Storico  43.780610
# 2          Massimo                 NaN     Centro Storico  43.766860
# 3      Max & Laura                 NaN     Centro Storico  43.779610
# 4          Stefano                 NaN     Centro Storico  43.771650
# ...            ...                 ...                ...        ...
# 32218       Egidio                 NaN             Modica  36.874222
# 32219     Concetta                 NaN            Pachino  36.691290
# 32220        David                 NaN           Trentino  46.258570
# 32221        Paolo                 NaN           Trentino  46.260730
# 32222      Lorenzo                 NaN           Trentino  46.143130
#
#        longitude           coordinates        room_type  price  \
# 0      11.210410    43.73198, 11.21041  Entire home/apt    250
# 1      11.243500     43.78061, 11.2435  Entire home/apt    250
# 2      11.252790    43.76686, 11.25279  Entire home/apt    250
# 3      11.260730    43.77961, 11.26073  Entire home/apt    250
# 4      11.255690    43.77165, 11.25569  Entire home/apt    250
# ...          ...                   ...              ...    ...
# 32218  14.764204  36.874222, 14.764204  Entire home/apt     30
# 32219  15.038440    36.69129, 15.03844  Entire home/apt     30
# 32220  10.587660    46.25857, 10.58766  Entire home/apt     30
# 32221  10.587190    46.26073, 10.58719  Entire home/apt     30
# 32222  10.964830    46.14313, 10.96483  Entire home/apt     30
#
#        minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0                   1                591   5/27/2022               5.55
# 1                   2                114  12/10/2021               1.96
# 2                   3                 61   5/22/2022               0.94
# 3                   1                 29   8/26/2021               0.49
# 4                   3                114   5/27/2022               1.93
# ...               ...                ...         ...                ...
# 32218               1                  2   5/15/2022               0.95
# 32219               2                 16   8/19/2021               0.26
# 32220               3                 38   2/26/2022               0.43
# 32221               2                 36    3/8/2022               0.50
# 32222               2                 48   5/29/2022               0.75
#
#        calculated_host_listings_count  availability_365  \
# 0                                  13               266
# 1                                   2               150
# 2                                   1               157
# 3                                   6                 0
# 4                                  10               217
# ...                               ...               ...
# 32218                               1               323
# 32219                               1               178
# 32220                               1                 0
# 32221                               1                 0
# 32222                               2                10
#
#        number_of_reviews_ltm license
# 0                         82     NaN
# 1                          3     NaN
# 2                          7     NaN
# 3                          4     NaN
# 4                         23     NaN
# ...                      ...     ...
# 32218                      2     NaN
# 32219                      3     NaN
# 32220                      4     NaN
# 32221                      4     NaN
# 32222                     11     NaN
#
# [32223 rows x 20 columns]

# %%
df_list = []

cities = ['Bergamo', 'Bologna', 'Florence', 'Milan', 'Naples', 'Puglia', 'Rome', 'Sicily', 'Trentino', 'Venice']

for i in (range(0,10)):
    city = df[df['City']==cities[i]]
    temp = city.sample(n=300, random_state=5)
    print("line ", i)
    print(temp.nunique())
    df_list.append(temp)

df_s = pd.concat(df_list)
# Out:
# line  0
# City                                1
# id                                300
# name                              300
# host_id                           261
# host_name                         175
# neighbourhood_group                 0
# neighbourhood                      85
# latitude                          298
# longitude                         294
# coordinates                       299
# room_type                           1
# price                             105
# minimum_nights                     11
# number_of_reviews                  68
# last_review                       145
# reviews_per_month                 120
# calculated_host_listings_count     13
# availability_365                  174
# number_of_reviews_ltm              28
# license                            69
# dtype: int64
# line  1
# City                                1
# id                                297
# name                              300
# host_id                           214
# host_name                         152
# neighbourhood_group                 0
# neighbourhood                       6
# latitude                          281
# longitude                         288
# coordinates                       294
# room_type                           1
# price                             125
# minimum_nights                     12
# number_of_reviews                 107
# last_review                       109
# reviews_per_month                 188
# calculated_host_listings_count     24
# availability_365                  194
# number_of_reviews_ltm              50
# license                            20
# dtype: int64
# line  2
# City                                1
# id                                297
# name                              300
# host_id                           265
# host_name                         184
# neighbourhood_group                 0
# neighbourhood                       5
# latitude                          285
# longitude                         288
# coordinates                       300
# room_type                           1
# price                             131
# minimum_nights                      9
# number_of_reviews                 133
# last_review                       116
# reviews_per_month                 181
# calculated_host_listings_count     32
# availability_365                  190
# number_of_reviews_ltm              51
# license                            30
# dtype: int64
# line  3
# City                                1
# id                                300
# name                              300
# host_id                           246
# host_name                         172
# neighbourhood_group                 0
# neighbourhood                      66
# latitude                          293
# longitude                         296
# coordinates                       298
# room_type                           1
# price                             133
# minimum_nights                     25
# number_of_reviews                  72
# last_review                       184
# reviews_per_month                 107
# calculated_host_listings_count     40
# availability_365                  151
# number_of_reviews_ltm              19
# license                            47
# dtype: int64
# line  4
# City                                1
# id                                298
# name                              299
# host_id                           266
# host_name                         180
# neighbourhood_group                 0
# neighbourhood                      26
# latitude                          292
# longitude                         289
# coordinates                       297
# room_type                           1
# price                             107
# minimum_nights                     10
# number_of_reviews                  68
# last_review                       158
# reviews_per_month                  97
# calculated_host_listings_count     18
# availability_365                  165
# number_of_reviews_ltm              14
# license                            27
# dtype: int64
# line  5
# City                                1
# id                                300
# name                              300
# host_id                           290
# host_name                         196
# neighbourhood_group                 6
# neighbourhood                      95
# latitude                          300
# longitude                         299
# coordinates                       300
# room_type                           1
# price                             118
# minimum_nights                      9
# number_of_reviews                  45
# last_review                       131
# reviews_per_month                  79
# calculated_host_listings_count     32
# availability_365                  195
# number_of_reviews_ltm              17
# license                            58
# dtype: int64
# line  6
# City                                1
# id                                300
# name                              299
# host_id                           287
# host_name                         199
# neighbourhood_group                 0
# neighbourhood                      15
# latitude                          296
# longitude                         300
# coordinates                       300
# room_type                           1
# price                             114
# minimum_nights                     16
# number_of_reviews                  81
# last_review                       178
# reviews_per_month                 117
# calculated_host_listings_count     26
# availability_365                  163
# number_of_reviews_ltm              17
# license                            56
# dtype: int64
# line  7
# City                                1
# id                                299
# name                              300
# host_id                           295
# host_name                         188
# neighbourhood_group                 0
# neighbourhood                      89
# latitude                          298
# longitude                         299
# coordinates                       299
# room_type                           1
# price                             122
# minimum_nights                      9
# number_of_reviews                  59
# last_review                       154
# reviews_per_month                  99
# calculated_host_listings_count     30
# availability_365                  188
# number_of_reviews_ltm              22
# license                            11
# dtype: int64
# line  8
# City                                1
# id                                300
# name                              300
# host_id                           272
# host_name                         191
# neighbourhood_group                 0
# neighbourhood                       2
# latitude                          300
# longitude                         299
# coordinates                       300
# room_type                           1
# price                             123
# minimum_nights                      9
# number_of_reviews                  49
# last_review                       136
# reviews_per_month                  91
# calculated_host_listings_count     27
# availability_365                  190
# number_of_reviews_ltm              21
# license                            71
# dtype: int64
# line  9
# City                                1
# id                                300
# name                              299
# host_id                           256
# host_name                         197
# neighbourhood_group                 2
# neighbourhood                      32
# latitude                          289
# longitude                         292
# coordinates                       299
# room_type                           1
# price                             131
# minimum_nights                     13
# number_of_reviews                 102
# last_review                       147
# reviews_per_month                 131
# calculated_host_listings_count     26
# availability_365                  167
# number_of_reviews_ltm              20
# license                            59
# dtype: int64

# %%
#df_s.set_index('id')
df_ss = df_s.pivot_table(index='id', columns='City', values='price')
df_ss.head()
# Out:
# City     Bergamo  Bologna  Florence  Milan  Naples  Puglia  Rome  Sicily  \
# id
# 15542.0     88.0      NaN       NaN    NaN     NaN     NaN   NaN     NaN
# 42196.0      NaN     70.0       NaN    NaN     NaN     NaN   NaN     NaN
# 52543.0      NaN      NaN      70.0    NaN     NaN     NaN   NaN     NaN
# 54991.0      NaN      NaN       NaN    NaN     NaN     NaN  63.0     NaN
# 70621.0      NaN      NaN       NaN    NaN     NaN     NaN  98.0     NaN
#
# City     Trentino  Venice
# id
# 15542.0       NaN     NaN
# 42196.0       NaN     NaN
# 52543.0       NaN     NaN
# 54991.0       NaN     NaN
# 70621.0       NaN     NaN

# %%
df_s.count()
# Out:
# City                              3000
# id                                3000
# name                              3000
# host_id                           3000
# host_name                         2999
# neighbourhood_group                600
# neighbourhood                     3000
# latitude                          3000
# longitude                         3000
# coordinates                       3000
# room_type                         3000
# price                             3000
# minimum_nights                    3000
# number_of_reviews                 3000
# last_review                       3000
# reviews_per_month                 3000
# calculated_host_listings_count    3000
# availability_365                  3000
# number_of_reviews_ltm             3000
# license                            455
# dtype: int64

# %%
import seaborn as sns

corr = df_ss.corr()
sns.heatmap(corr,vmin=-1, vmax=1, annot=True)

# alright given this table below, we can pick and choose a few pairs of cities to compare using t-test
# Out:
# 97.25916270986562

# %%
# Find the population mean
mu = df['price'].mean()
sd = df['price'].std()
mu
# Out:
# 97.25916270986562

# %%
from statsmodels.stats.weightstats import ztest as ztest

tests = []

# perform one sample z-test for each city against the population mean:
for i in (range(0,10)):
    t, p = ztest(df[df['City']==cities[i]]['price'], value=mu)
    city_mean = df[df['City']==cities[i]]['price'].mean()
    temp = [cities[i], t, p, city_mean]
    tests.append(temp)

tests
# Out:
# [['Bergamo', -7.0446933676869685, 1.8587036237231e-12, 86.34389857369256],
#  ['Bologna', 4.6949071274996825, 2.6672787872203993e-06, 102.98448979591836],
#  ['Florence', 21.348734474795695, 4.006413891155802e-101, 118.09975412715139],
#  ['Milan', 10.587584317211457, 3.402593957401219e-26, 113.25250192455735],
#  ['Naples', -0.6171830357186693, 0.5371140038892432, 95.88674698795181],
#  ['Puglia', -7.178945655354418, 7.025106130033208e-13, 93.91860836259177],
#  ['Rome', 8.141884049987372, 3.891738630875675e-16, 110.37589285714286],
#  ['Sicily', -20.49217182114831, 2.528582907588778e-93, 89.17256988564168],
#  ['Trentino', 11.910433243863032, 1.0443322324413298e-32, 108.00297239915075],
#  ['Venice', 13.74406103912904, 5.5285655390774935e-43, 137.16176470588235]]

# %%
# fit these into a dataframe:

df_results = pd.DataFrame(tests)
df_results.columns = ['city', 'test-statistic', 'p-value', 'mean price (€)']

df_results.sort_values('mean price (€)', ascending=False)
# Out:
#        city  test-statistic        p-value  mean price (€)
# 9    Venice       13.744061   5.528566e-43      137.161765
# 2  Florence       21.348734  4.006414e-101      118.099754
# 3     Milan       10.587584   3.402594e-26      113.252502
# 6      Rome        8.141884   3.891739e-16      110.375893
# 8  Trentino       11.910433   1.044332e-32      108.002972
# 1   Bologna        4.694907   2.667279e-06      102.984490
# 4    Naples       -0.617183   5.371140e-01       95.886747
# 5    Puglia       -7.178946   7.025106e-13       93.918608
# 7    Sicily      -20.492172   2.528583e-93       89.172570
# 0   Bergamo       -7.044693   1.858704e-12       86.343899

# %%
# Out:
#        city    z-score        p-value
# 0   Bergamo  -7.044693   1.858704e-12
# 1   Bologna   4.694907   2.667279e-06
# 2  Florence  21.348734  4.006414e-101
# 3     Milan  10.587584   3.402594e-26
# 4    Naples  -0.617183   5.371140e-01
# 5    Puglia  -7.178946   7.025106e-13
# 6      Rome   8.141884   3.891739e-16
# 7    Sicily -20.492172   2.528583e-93
# 8  Trentino  11.910433   1.044332e-32
# 9    Venice  13.744061   5.528566e-43
